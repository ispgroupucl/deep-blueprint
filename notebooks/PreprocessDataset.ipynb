# %%
# %load_ext autoreload
# %autoreload 2

# %%
from bioblue.nb import *
from itkwidgets import compare
from bioblue.dataset import preprocess as bb_preprocess

# %%
bb_preprocess("Task202_KidneyVessels", {
#     "s1": ("200803 Kidney THS 1-07/RT/JPG", None),
    "s2": ("200803 Kidney THS 1-11/RT/JPG", "200803 Kidney THS 1-11/RT/BIN"),
#     "s3": ("200803 Kidney THS 1-12/RT/JPG", "200803 Kidney THS 1-12/RT/BIN"), # Done by Arne
#     "s4": ("200805 Kidney THS 1-58/RT/JPG", None),
#     "s5": ("200805 Kidney THS 1-62/RT/JPG", None),
}, partition="train", split=1, resize=False, file_suffix=".jpg", output_name="Task202_KidneyVessels_RT2")
# Out:
# s2
#   0%|          | 0/2400 [00:00<?, ?it/s]
# /home/vjoosdeterbe/projects/bb-data/Task202_KidneyVessels/200803 Kidney THS 1-11/RT/BIN 0000
# /home/vjoosdeterbe/projects/bb-data/Task202_KidneyVessels/200803 Kidney THS 1-11/RT/BIN 0001
# /home/vjoosdeterbe/projects/bb-data/Task202_KidneyVessels/200803 Kidney THS 1-11/RT/BIN 0002
# /home/vjoosdeterbe/projects/bb-data/Task202_KidneyVessels/200803 Kidney THS 1-11/RT/BIN 0003
# /home/vjoosdeterbe/projects/bb-data/Task202_KidneyVessels/200803 Kidney THS 1-11/RT/BIN 0004
# /home/vjoosdeterbe/projects/bb-data/Task202_KidneyVessels/200803 Kidney THS 1-11/RT/BIN 0005
# /home/vjoosdeterbe/projects/bb-data/Task202_KidneyVessels/200803 Kidney THS 1-11/RT/BIN 0006
# /home/vjoosdeterbe/projects/bb-data/Task202_KidneyVessels/200803 Kidney THS 1-11/RT/BIN 0007
# /home/vjoosdeterbe/projects/bb-data/Task202_KidneyVessels/200803 Kidney THS 1-11/RT/BIN 0008
# /home/vjoosdeterbe/projects/bb-data/Task202_KidneyVessels/200803 Kidney THS 1-11/RT/BIN 0009
# ...

# %%
# preprocess("Task203_BrainVessels", {
#     "PA2-9d-l1": ("SegmentedTissueRegistered", "LabelsRegistered"),
#     "PA2-9d-l2": ("SegmentedTissueRegistered", "BetterLabelsRegistered"),
# #     "PA1-9d": ("PA1_9d", None),
# #     "PA2-9d": ("PA2_9d", None),
# #     "PA3-9d": ("PA3_9d", None),
# }, prefix="d", resize=(512,512))

# %%
bb_preprocess("Task201_BoneVessels", {
    "s1_ref": ("neoscan_ii-bone_s1_ref", "neoscan_ii-bone_s1_ref_blood_vessel_bin"),
    "s1859": ("1859/1859_slices", "1859/1859_binary"),
    "s1872": ("1872/1872_slices", "1872/1872_binary"),
    "s1880": ("1880/1880_slices", "1880/1880_binary"),
#     "s1_noisy": ("neoscan_ii-bone_s1_noisy", "neoscan_ii-bone_s1_noisy_blood_vessel_bin"),
}, prefix="_", labeled_dir="train", split=1, output_name="Task201_BoneVessels_original", resize=False)
bb_preprocess("Task201_BoneVessels", {
    "s1_noisy": ("neoscan_ii-bone_s1_noisy", "neoscan_ii-bone_s1_noisy_blood_vessel_bin"),
}, prefix="_", labeled_dir="test", output_name="Task201_BoneVessels_original", resize=False)
# Out:
# s1_ref
#   0%|          | 0/1043 [00:00<?, ?it/s]
# s1859
#   0%|          | 0/1003 [00:00<?, ?it/s]
# s1872
#   0%|          | 0/1001 [00:00<?, ?it/s]
# s1880
#   0%|          | 0/1001 [00:00<?, ?it/s]
# s1_noisy
#   0%|          | 0/1043 [00:00<?, ?it/s]
