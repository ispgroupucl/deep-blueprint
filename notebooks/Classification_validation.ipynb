# %%
import wandb
# import util
import matplotlib.pyplot as plt
import numpy as np
import os
from PIL import Image
import shutil
import wandb
from PIL import Image
import os
import glob
from pathlib import Path

from tqdm.notebook import tqdm
from skimage.io import imread,imsave

# %%
# %reload_ext autoreload
# %autoreload 2

from bioblue.nb.load import load_from_dir, load_from_dir2
# from bioblue.nb import *

# %%
# # Binary Classifier
# run_dir = Path("/home/sayez/Deepsun/bio-blueprints/outputs/2022-07-12/15-34-53")

#ABCDJ Classifier
run_dir = Path("/home/sayez/Deepsun/bio-blueprints/outputs/2022-07-13/13-37-15")

# %%
config, model, dm, trainer = load_from_dir2(
                                    run_path= run_dir,
                                    load_trainer=True,
                                    override = [
#                                         '~callbacks.wandb',
                                        # f'callbacks.Save_prediction.output_dir={str(run_dir/"predictions")}'
                                    ]
                                )

results = trainer.test(model, datamodule=dm)
# Out:
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help`
#        for usage information.
#
# /usr/bin/nvidia-modprobe: unrecognized option: "-s"
#
# ERROR: Invalid commandline, please run `/usr/bin/nvidia-modprobe --help`
#        for usage information.
#
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# `Trainer(val_check_interval=1.0)` was configured so validation will run at the end of the training epoch..
# ['image', 'T400-T350-Alternating']
# ['A', 'B', 'C', 'D', 'J']
# ['image', 'T400-T350-Alternating']
# ['A', 'B', 'C', 'D', 'J']
# ['image', 'T400-T350-Alternating']
# ['A', 'B', 'C', 'D', 'J']
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# Testing: 0it [00:00, ?it/s]
# Accuracy on batch: 0.5625
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# C C
# C J
# D C
# J A
# D B
# D D
# C C
# D C
# C C
# C D
# B B
# D D
# A A
# B B
# D D
# C J
# Accuracy on batch: 0.5
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# B B
# C J
# C D
# C C
# C B
# D B
# C D
# D D
# D D
# C D
# D C
# D D
# D C
# C C
# C C
# C C
# Accuracy on batch: 0.6875
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# A A
# D J
# B B
# C C
# B B
# J C
# B B
# J J
# J J
# J J
# D B
# J C
# B B
# D D
# J C
# A A
# Accuracy on batch: 0.5625
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# A A
# A A
# A A
# B D
# B D
# B B
# B A
# J J
# A A
# A A
# A A
# A A
# B C
# J C
# J A
# J C
# Accuracy on batch: 0.375
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# B A
# D D
# D D
# B A
# D C
# A A
# J A
# J J
# C A
# C A
# C D
# A J
# C D
# J J
# D D
# B A
# Accuracy on batch: 0.5625
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# D C
# D C
# D D
# B B
# D D
# A A
# J J
# B A
# A A
# C B
# A A
# D C
# A D
# D D
# A D
# D D
# Accuracy on batch: 0.5625
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# D D
# A A
# J A
# A B
# J J
# A J
# B A
# J A
# A A
# J D
# C A
# B B
# B B
# B B
# D D
# C C
# Accuracy on batch: 0.5
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# J J
# A A
# C C
# D C
# A J
# J C
# B B
# B D
# D D
# B D
# C B
# C A
# B D
# B B
# C C
# D D
# Accuracy on batch: 0.3125
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# C J
# B B
# A C
# C J
# B B
# A A
# J J
# B A
# A J
# J C
# B A
# C D
# B A
# A A
# B C
# C J
# Accuracy on batch: 0.75
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# J J
# B D
# A A
# C B
# D D
# C C
# J B
# A A
# A A
# D D
# D D
# A A
# J A
# A A
# B B
# J J
# Accuracy on batch: 0.625
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# B B
# C D
# C D
# J J
# D D
# B A
# C D
# J J
# D D
# C C
# C A
# D D
# J A
# A A
# J J
# B B
# Accuracy on batch: 0.5625
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# J J
# B B
# C C
# B A
# J J
# J J
# B A
# A B
# D D
# J J
# D C
# A A
# J J
# A B
# A B
# D B
# Accuracy on batch: 0.75
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# D D
# A A
# A A
# A A
# B A
# C D
# A J
# A A
# D D
# J J
# A A
# A A
# J J
# J A
# J J
# J J
# Accuracy on batch: 0.5625
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# B A
# C B
# C B
# D D
# A A
# J J
# C C
# A A
# J C
# B B
# C C
# B C
# B D
# J J
# J C
# D D
# Accuracy on batch: 0.375
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# B D
# B A
# B A
# D D
# A J
# B C
# A A
# C D
# J J
# C D
# B A
# D C
# D D
# D D
# C C
# A B
# Accuracy on batch: 0.800000011920929
# {'0': 'A', '1': 'B', '2': 'C', '3': 'D', '4': 'J'}
# D D
# J J
# J C
# D D
# J J
# A A
# C C
# C C
# J J
# C J
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      test_acc_epoch         0.5600000023841858
#      test_loss_epoch        1.0537077188491821
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.24.1
