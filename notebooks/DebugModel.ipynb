# %%
from bioblue.nb import *

# %%
cfg, model, dm, trainer = load_from_overrides([
    "gpus=[0]",
    "exp=Threshold",
    "trainer.max_epochs=1",
    "dataset.batch_size=8",
    "dataset=kidneys",
    "module=base_segmentation",
    "model=big_unet",
    "+module.lr=1e-4",
    "model.input_format=['image']",
    "+module.class_weights=[1,3]",
    "dataset.strategies.kfold.fold=0",
    # "+callback}: {s.shape}ks.image={_target_:bioblue.callback.PlotImageCallback}",
    "+callbacks.train_image={_target_:bioblue.callback.PlotTrainCallback, show_percentage:0.01}",
    "+callbacks.volume={_target_:bioblue.callback.SaveVolumeCallback, train:true}",
    "+trainer.limit_train_batches=1",
    "+trainer.limit_val_batches=1",
    "hydra.verbose=bioblue.callback",
], load_trainer=True)

trainer.fit(model, datamodule=dm)
# Out:
# GPU available: True, used: True
# TPU available: None, using: 0 TPU cores
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0,1,2,3]
# [2021-04-15 12:06:12,642][botocore.credentials][INFO] - Found credentials in environment variables.
# [2021-04-15 12:06:13,961][bioblue.dataset.strategy.mip][WARNING] - /home/vjoosdeterbe/projects/bio-blueprints/data/Task202_KidneyVessels/train/mip-image already exists, skipping creation.
# [2021-04-15 12:06:15,405][bioblue.dataset.strategy.split][INFO] - Split #1/5 : 4239 samples for train and 2400 for validation. (starting from 0 to 1)
#  training set containing ['s5_0-1038.npz', 's4_0-2399.npz', 's2_0-2399.npz', 's3_0-2399.npz']
# [2021-04-15 12:06:15,460][bioblue.dataset.datamodule][INFO] - train size: 4239; val size: 2400
#   | Name      | Type             | Params
# -----------------------------------------------
# 0 | loss      | CrossEntropyLoss | 0
# 1 | segmenter | ConfUnet         | 32.7 M
# 2 | iou       | ModuleDict       | 0
# ...
